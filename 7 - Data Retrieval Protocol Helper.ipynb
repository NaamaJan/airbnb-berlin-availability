# %% [markdown]
# # 7 - Data Retrieval Protocol Helper
# This notbook assists filling out "Data Retrieval Protocol.xlsx".
# For each source of data we get datafarme which desribe the features (and dumping the results to 'data_retrieval_protocol_helper.csv').
# Using this csv for cutting results from it to "Data Retrieval Protocol.xlsx".
# This notbook support the following columns:
# * "Feature name"
# * "Source"
# * "Unique count"
# * "Min"
# * "Max"
# * "Notes"

# %%
# Import libraries:
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

from random import sample
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from pandas.api.types import is_datetime64_any_dtype

# %%
def drop_additional_index_columns(_df):
    # dropping additional index columns that start with "Unnamed" - dropping these columns
    columns_to_drop = [x for x in _df.columns.to_list() if x.startswith("Unnamed")]
    print("dropping coulmns: ", columns_to_drop) # [Unamed..., Unamed..]
    return _df.drop(columns=columns_to_drop, axis=1, inplace=False)

# %%
def get_features_info(_df, _source):
    features_info_list = []
    for feature_name in _df.columns:
        sum_of_na =  _df[feature_name].isna().sum()
        unique_value = _df[feature_name].unique().tolist()
        smaple_values = sample(unique_value,5  if len(unique_value)> 5 else len(unique_value))
        is_numeric = is_numeric_dtype(_df[feature_name])
        is_string = is_string_dtype(_df[feature_name])
        is_datetime = is_datetime64_any_dtype(_df[feature_name])
        record = {"Feature name": feature_name,
                 "Source": _source,
                 "Unique count": len(_df[feature_name].unique()),
                 "Min": _df[feature_name].min() if is_numeric else "",
                 "Max": _df[feature_name].max() if is_numeric else "",
                 "Notes": {"smaple_values": smaple_values, 
                          "sum_of_na": sum_of_na, 
                          "is_numeric": is_numeric,  
                          "is_string": is_string, 
                          "is_datetime": is_datetime}
                 }
        features_info_list.append(record)
        
    return pd.DataFrame(features_info_list)

# %% [markdown]
# ### 1. Kaggle Source Data

# %%
df_kaggle_flat_file = pd.read_csv("flat_file.csv")
df_kaggle_flat_file = drop_additional_index_columns(df_kaggle_flat_file)
df_kaggle_flat_file.info(verbose=True, show_counts=True)
# Out:
# C:\Users\itzikjan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (105,109) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# dropping coulmns:  ['Unnamed: 0']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157864 entries, 0 to 157863
# Data columns (total 109 columns):
#  #    Column                                 Non-Null Count   Dtype
# ---   ------                                 --------------   -----
#  0    listing_id                             157864 non-null  int64
#  1    name                                   157451 non-null  object
#  2    target_start_date_period               157864 non-null  object
#  3    target_end_date_period                 157864 non-null  object
#  4    target_num_of_day_in_period            157864 non-null  int64
#  5    target_num_of_booked_days              157864 non-null  int64
#  6    booked_up_target                       157864 non-null  int64
#  7    target_avg_dollar_price_in_period      43919 non-null   float64
#  8    start_date_previous_period             157864 non-null  object
#  9    end_date_previous_period               157864 non-null  object
#  10   num_of_day_in_previous_period          157864 non-null  int64
#  11   num_of_booked_days_in_previous_period  157864 non-null  int64
#  12   occupancy_last_period                  157864 non-null  float64
#  13   avg_dollar_price_in_previous_period    78311 non-null   float64
#  14   host_id                                157864 non-null  int64
#  15   host_name                              157682 non-null  object
#  16   neighbourhood_group                    157864 non-null  object
#  17   neighbourhood                          157864 non-null  object
#  18   latitude                               157864 non-null  float64
#  19   longitude                              157864 non-null  float64
#  20   room_type                              157864 non-null  object
#  21   price                                  157864 non-null  float64
#  22   minimum_nights                         157864 non-null  float64
#  23   number_of_reviews                      157864 non-null  float64
#  24   last_review                            130508 non-null  object
#  25   DaysPassed_last_review                 130508 non-null  float64
#  26   reviews_per_month                      130466 non-null  float64
#  27   calculated_host_listings_count         157864 non-null  float64
#  28   availability_365                       157864 non-null  float64
#  29   listing_url                            157864 non-null  object
#  30   scrape_id                              157864 non-null  float64
#  31   last_scraped                           157864 non-null  object
#  32   summary                                151074 non-null  object
#  33   space                                  97916 non-null   object
#  34   description                            156429 non-null  object
#  35   experiences_offered                    157864 non-null  object
#  36   notes                                  50295 non-null   object
#  37   transit                                91168 non-null   object
#  38   access                                 75089 non-null   object
#  39   interaction                            72688 non-null   object
#  40   house_rules                            69923 non-null   object
#  41   neighborhood_overview                  80668 non-null   object
#  42   host_about                             78316 non-null   object
#  43   host_since                             157682 non-null  object
#  44   DaysPassed_host_since                  157682 non-null  float64
#  45   picture_url                            157864 non-null  object
#  46   host_url                               157864 non-null  object
#  47   host_location                          157052 non-null  object
#  48   host_response_time                     67606 non-null   object
#  49   host_response_rate                     67599 non-null   float64
#  50   host_is_superhost                      157682 non-null  object
#  51   host_thumbnail_url                     157682 non-null  object
#  52   host_picture_url                       157682 non-null  object
#  53   host_neighbourhood                     122206 non-null  object
#  54   host_total_listings_count              157682 non-null  float64
#  55   host_verifications                     157864 non-null  object
#  56   host_has_profile_pic                   157682 non-null  object
#  57   host_identity_verified                 157682 non-null  object
#  58   street                                 157864 non-null  object
#  59   neighbourhood_cleansed                 157864 non-null  object
#  60   neighbourhood_group_cleansed           157864 non-null  object
#  61   city                                   157829 non-null  object
#  62   state                                  157276 non-null  object
#  63   zipcode                                153209 non-null  float64
#  64   smart_location                         157864 non-null  object
#  65   market                                 157423 non-null  object
#  66   country_code                           157864 non-null  object
#  67   country                                157864 non-null  object
#  68   is_location_exact                      157864 non-null  object
#  69   property_type                          157864 non-null  object
#  70   accommodates                           157864 non-null  float64
#  71   bathrooms                              157640 non-null  float64
#  72   bedrooms                               157738 non-null  float64
#  73   beds                                   157584 non-null  float64
#  74   bed_type                               157864 non-null  object
#  75   amenities                              157864 non-null  object
#  76   square_feet                            3122 non-null    float64
#  77   weekly_price                           25767 non-null   object
#  78   monthly_price                          18613 non-null   object
#  79   security_deposit                       92337 non-null   object
#  80   cleaning_fee                           107842 non-null  object
#  81   guests_included                        157864 non-null  float64
#  82   extra_people                           157864 non-null  object
#  83   maximum_nights                         157864 non-null  float64
#  84   calendar_updated                       157864 non-null  object
#  85   availability_30                        157864 non-null  float64
#  86   availability_60                        157864 non-null  float64
#  87   availability_90                        157864 non-null  float64
#  88   first_review                           130466 non-null  object
#  89   DaysPassed_first_review                130466 non-null  float64
#  90   calendar_last_scraped                  157864 non-null  object
#  91   review_scores_rating                   127141 non-null  float64
#  92   review_scores_accuracy                 126966 non-null  float64
#  93   review_scores_cleanliness              126987 non-null  float64
#  94   review_scores_checkin                  126840 non-null  float64
#  95   review_scores_communication            126938 non-null  float64
#  96   review_scores_location                 126847 non-null  float64
#  97   review_scores_value                    126819 non-null  float64
#  98   license                                11466 non-null   object
#  99   instant_bookable                       157864 non-null  object
#  100  is_business_travel_ready               157864 non-null  object
#  101  require_guest_profile_picture          157864 non-null  object
#  102  require_guest_phone_verification       157864 non-null  object
#  103  cancellation_policy                    157864 non-null  object
#  104  concat_comments                        85155 non-null   object
#  105  size                                   75285 non-null   float64
#  106  concat_comments_polarity               85155 non-null   float64
#  107  concat_comments_subjectivity           85155 non-null   float64
#  108  concat_comments_sentiment              85155 non-null   object
# dtypes: float64(38), int64(7), object(64)
# memory usage: 131.3+ MB

# %%
df_kaggle_flat_file_features_info = get_features_info(df_kaggle_flat_file, "kaggle_flat_table")
df_kaggle_flat_file_features_info.head(5)
# Out:
#                   Feature name             Source  Unique count   Min  \
# 0                   listing_id  kaggle_flat_table         22552  2015
# 1                         name  kaggle_flat_table         21874
# 2     target_start_date_period  kaggle_flat_table             7
# 3       target_end_date_period  kaggle_flat_table             8
# 4  target_num_of_day_in_period  kaggle_flat_table             5    89
#
#         Max                                              Notes
# 0  29867352  {'smaple_values': [29605459, 23740543, 1282470...
# 1            {'smaple_values': ['Room in Wilmersdorf (only ...
# 2            {'smaple_values': ['2019-05-01', '2019-07-01',...
# 3            {'smaple_values': ['2019-04-30', '2019-11-06',...
# 4       100  {'smaple_values': [92, 89, 100, 91, 98], 'sum_...

# %% [markdown]
# ### 2. Climatestotravel Berlin Sources Data

# %%
df_climatestotravel_berlin_sunshine_hours = pd.read_csv("climatestotravel Berlin - Sunshine hours.csv")
df_climatestotravel_berlin_sunshine_hours = drop_additional_index_columns(df_climatestotravel_berlin_sunshine_hours)
display(df_climatestotravel_berlin_sunshine_hours.info(verbose=True, show_counts=True))

df_climatestotravel_berlin_average_precipitation = pd.read_csv("climatestotravel Berlin - Average precipitation.csv")
df_climatestotravel_berlin_average_precipitation = drop_additional_index_columns(df_climatestotravel_berlin_average_precipitation)
display(df_climatestotravel_berlin_average_precipitation.info(verbose=True, show_counts=True))

df_climatestotravel_berlin_average_temperatures = pd.read_csv("climatestotravel Berlin - Average temperatures.csv")
df_climatestotravel_berlin_average_temperatures = drop_additional_index_columns(df_climatestotravel_berlin_average_temperatures)
display(df_climatestotravel_berlin_average_temperatures.info(verbose=True, show_counts=True))
# Out:
# dropping coulmns:  []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    13 non-null     object
#  1   Average  13 non-null     float64
#  2   Total    13 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 440.0+ bytes
# None
# dropping coulmns:  []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        13 non-null     object
#  1   Millimeters  13 non-null     int64
#  2   Inches       13 non-null     float64
#  3   Days         13 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 544.0+ bytes
# None
# dropping coulmns:  []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      13 non-null     object
#  1   Min (°C)   13 non-null     float64
#  2   Max (°C)   13 non-null     float64
#  3   Mean (°C)  13 non-null     float64
#  4   Min (°F)   13 non-null     float64
#  5   Max (°F)   13 non-null     float64
#  6   Mean (°F)  13 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 856.0+ bytes
# None

# %%
df_climatestotravel_berlin_sunshine_hours_info = get_features_info(df_climatestotravel_berlin_sunshine_hours, "climatestotravel_berlin_sunshine_hours")
display(df_climatestotravel_berlin_sunshine_hours_info.head(3))

df_climatestotravel_berlin_average_precipitation_info = get_features_info(df_climatestotravel_berlin_average_precipitation, "climatestotravel_berlin_average_precipitation_")
display(df_climatestotravel_berlin_average_precipitation_info.head(3))

df_climatestotravel_berlin_average_temperatures_info = get_features_info(df_climatestotravel_berlin_average_temperatures, "climatestotravel_berlin_average_temperaturess")
display(df_climatestotravel_berlin_average_temperatures_info.head(3))
# Out:
#   Feature name                                  Source  Unique count  Min  \
# 0        Month  climatestotravel_berlin_sunshine_hours            13
# 1      Average  climatestotravel_berlin_sunshine_hours            10  1.5
# 2        Total  climatestotravel_berlin_sunshine_hours            12   40
#
#     Max                                              Notes
# 0        {'smaple_values': ['February', 'June', 'May', ...
# 1   7.5  {'smaple_values': [1.5, 3.5, 2.5, 4.7, 2.0], '...
# 2  1705  {'smaple_values': [40, 230, 120, 220, 55], 'su...
#   Feature name                                          Source  Unique count  \
# 0        Month  climatestotravel_berlin_average_precipitation_            13
# 1  Millimeters  climatestotravel_berlin_average_precipitation_             7
# 2       Inches  climatestotravel_berlin_average_precipitation_             7
#
#    Min   Max                                              Notes
# 0             {'smaple_values': ['February', 'July', 'Year',...
# 1   35   570  {'smaple_values': [55, 40, 60, 35, 70], 'sum_o...
# 2  1.4  22.4  {'smaple_values': [1.8, 2.8, 1.4, 2.2, 1.6], '...
#   Feature name                                         Source  Unique count  \
# 0        Month  climatestotravel_berlin_average_temperaturess            13
# 1     Min (°C)  climatestotravel_berlin_average_temperaturess            11
# 2     Max (°C)  climatestotravel_berlin_average_temperaturess             9
#
#    Min   Max                                              Notes
# 0             {'smaple_values': ['January', 'November', 'Jun...
# 1 -2.0  14.0  {'smaple_values': [11.0, 12.0, 4.0, 2.0, 9.0],...
# 2  3.0  24.0  {'smaple_values': [4.0, 3.0, 13.0, 24.0, 13.5]...

# %% [markdown]
# ### 3. Features Enrichment

# %%
df_flat_file_after_feature_enrichment = pd.read_csv("flat_file_after_feature_enrichment.csv")
df_flat_file_after_feature_enrichment = drop_additional_index_columns(df_flat_file_after_feature_enrichment)
df_flat_file_after_feature_enrichment.info(verbose=True, show_counts=True)
# Out:
# C:\Users\itzikjan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (51) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# dropping coulmns:  ['Unnamed: 0']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157864 entries, 0 to 157863
# Data columns (total 865 columns):
#  #    Column                                                                                                             Non-Null Count   Dtype
# ---   ------                                                                                                             --------------   -----
#  0    listing_id                                                                                                         157864 non-null  int64
#  1    name                                                                                                               157451 non-null  object
#  2    target_start_date_period                                                                                           157864 non-null  object
#  3    target_end_date_period                                                                                             157864 non-null  object
#  4    start_date_previous_period                                                                                         157864 non-null  object
#  5    end_date_previous_period                                                                                           157864 non-null  object
#  6    host_id                                                                                                            157864 non-null  int64
#  7    host_name                                                                                                          157682 non-null  object
#  8    neighbourhood                                                                                                      157864 non-null  object
#  9    latitude                                                                                                           157864 non-null  float64
#  10   longitude                                                                                                          157864 non-null  float64
#  11   last_review                                                                                                        130508 non-null  object
#  12   listing_url                                                                                                        157864 non-null  object
#  13   scrape_id                                                                                                          157864 non-null  float64
#  14   last_scraped                                                                                                       157864 non-null  object
#  15   summary                                                                                                            151074 non-null  object
#  16   space                                                                                                              97916 non-null   object
#  17   description                                                                                                        156429 non-null  object
#  18   experiences_offered                                                                                                157864 non-null  object
#  19   notes                                                                                                              50295 non-null   object
#  20   transit                                                                                                            91168 non-null   object
#  21   access                                                                                                             75089 non-null   object
#  22   interaction                                                                                                        72688 non-null   object
#  23   house_rules                                                                                                        69923 non-null   object
#  24   neighborhood_overview                                                                                              80668 non-null   object
#  25   host_about                                                                                                         78316 non-null   object
#  26   host_since                                                                                                         157682 non-null  object
#  27   picture_url                                                                                                        157864 non-null  object
#  28   host_url                                                                                                           157864 non-null  object
#  29   host_location                                                                                                      157052 non-null  object
#  30   host_thumbnail_url                                                                                                 157682 non-null  object
#  31   host_picture_url                                                                                                   157682 non-null  object
#  32   host_neighbourhood                                                                                                 122206 non-null  object
#  33   host_verifications                                                                                                 157864 non-null  object
#  34   street                                                                                                             157864 non-null  object
#  35   neighbourhood_cleansed                                                                                             157864 non-null  object
#  36   neighbourhood_group_cleansed                                                                                       157864 non-null  object
#  37   city                                                                                                               157829 non-null  object
#  38   state                                                                                                              157276 non-null  object
#  39   zipcode                                                                                                            153209 non-null  float64
#  40   smart_location                                                                                                     157864 non-null  object
#  41   market                                                                                                             157423 non-null  object
#  42   country_code                                                                                                       157864 non-null  object
#  43   country                                                                                                            157864 non-null  object
#  44   is_location_exact                                                                                                  157864 non-null  object
#  45   amenities                                                                                                          157864 non-null  object
#  46   calendar_updated                                                                                                   157864 non-null  object
#  47   first_review                                                                                                       130466 non-null  object
#  48   calendar_last_scraped                                                                                              157864 non-null  object
#  49   license                                                                                                            11466 non-null   object
#  50   concat_comments                                                                                                    85155 non-null   object
#  51   target_num_of_booked_days                                                                                          157864 non-null  int64
#  52   booked_up_target                                                                                                   157864 non-null  int64
#  53   num_of_day_in_previous_period                                                                                      157864 non-null  int64
#  54   num_of_booked_days_in_previous_period                                                                              157864 non-null  int64
#  55   price                                                                                                              157864 non-null  float64
#  56   minimum_nights                                                                                                     157864 non-null  float64
#  57   number_of_reviews                                                                                                  157864 non-null  float64
#  58   availability_365                                                                                                   157864 non-null  float64
#  59   accommodates                                                                                                       157864 non-null  float64
#  60   security_deposit                                                                                                   157864 non-null  float64
#  61   cleaning_fee                                                                                                       157864 non-null  float64
#  62   extra_people                                                                                                       157864 non-null  float64
#  63   maximum_nights                                                                                                     157864 non-null  float64
#  64   sqrt_calculated_host_listings_count                                                                                157864 non-null  float64
#  65   sigmoid_calculated_host_listings_count                                                                             157864 non-null  float64
#  66   sqrt_guests_included                                                                                               157864 non-null  float64
#  67   kmean_cluster_availability                                                                                         157864 non-null  int64
#  68   availability_60_minus_availability_90                                                                              157864 non-null  float64
#  69   availability_60_div_availability_90                                                                                75782 non-null   float64
#  70   availability_30_minus_availability_60                                                                              157864 non-null  float64
#  71   availability_30_div_availability_60                                                                                69867 non-null   float64
#  72   availability_365_minus_availability_90                                                                             157864 non-null  float64
#  73   availability_365_div_availability_90                                                                               82348 non-null   float64
#  74   availability_30_minus_availability_90                                                                              157864 non-null  float64
#  75   availability_30_div_availability_90                                                                                75782 non-null   float64
#  76   availability_365_minus_availability_60                                                                             157864 non-null  float64
#  77   availability_365_div_availability_60                                                                               82348 non-null   float64
#  78   target_num_of_day_in_period_minus_num_of_day_in_previous_period                                                    157864 non-null  int64
#  79   target_num_of_day_in_period_div_num_of_day_in_previous_period                                                      157864 non-null  float64
#  80   occupancy_last_period_minus_availability_60                                                                        157864 non-null  float64
#  81   occupancy_last_period_div_availability_60                                                                          157864 non-null  float64
#  82   occupancy_last_period_minus_availability_365                                                                       157864 non-null  float64
#  83   occupancy_last_period_div_availability_365                                                                         157864 non-null  float64
#  84   occupancy_last_period_minus_availability_90                                                                        157864 non-null  float64
#  85   occupancy_last_period_div_availability_90                                                                          157864 non-null  float64
#  86   room_type_Private room_host_response_time_within an hour                                                           157864 non-null  int64
#  87   room_type_Private room_host_response_time_within a few hours                                                       157864 non-null  int64
#  88   room_type_Private room_host_response_time_missing_host_response_time                                               157864 non-null  int64
#  89   room_type_Private room_host_response_time_within a day                                                             157864 non-null  int64
#  90   room_type_Private room_host_response_time_a few days or more                                                       157864 non-null  int64
#  91   room_type_Entire home/apt_host_response_time_within an hour                                                        157864 non-null  int64
#  92   room_type_Entire home/apt_host_response_time_within a few hours                                                    157864 non-null  int64
#  93   room_type_Entire home/apt_host_response_time_missing_host_response_time                                            157864 non-null  int64
#  94   room_type_Entire home/apt_host_response_time_within a day                                                          157864 non-null  int64
#  95   room_type_Entire home/apt_host_response_time_a few days or more                                                    157864 non-null  int64
#  96   room_type_Shared room_host_response_time_within an hour                                                            157864 non-null  int64
#  97   room_type_Shared room_host_response_time_missing_host_response_time                                                157864 non-null  int64
#  98   room_type_Shared room_host_response_time_within a day                                                              157864 non-null  int64
#  99   room_type_Shared room_host_response_time_a few days or more                                                        157864 non-null  int64
#  100  room_type_Private room_host_is_superhost_t                                                                         157864 non-null  int64
#  101  room_type_Private room_host_is_superhost_f                                                                         157864 non-null  int64
#  102  room_type_Private room_host_is_superhost_missing_host_is_superhost                                                 157864 non-null  int64
#  103  room_type_Entire home/apt_host_is_superhost_t                                                                      157864 non-null  int64
#  104  room_type_Entire home/apt_host_is_superhost_f                                                                      157864 non-null  int64
#  105  room_type_Entire home/apt_host_is_superhost_missing_host_is_superhost                                              157864 non-null  int64
#  106  room_type_Shared room_host_is_superhost_t                                                                          157864 non-null  int64
#  107  room_type_Shared room_host_is_superhost_f                                                                          157864 non-null  int64
#  108  room_type_Private room_host_has_profile_pic_t                                                                      157864 non-null  int64
#  109  room_type_Private room_host_has_profile_pic_f                                                                      157864 non-null  int64
#  110  room_type_Private room_host_has_profile_pic_missing_host_has_profile_pic                                           157864 non-null  int64
#  111  room_type_Entire home/apt_host_has_profile_pic_t                                                                   157864 non-null  int64
#  112  room_type_Entire home/apt_host_has_profile_pic_f                                                                   157864 non-null  int64
#  113  room_type_Entire home/apt_host_has_profile_pic_missing_host_has_profile_pic                                        157864 non-null  int64
#  114  room_type_Shared room_host_has_profile_pic_t                                                                       157864 non-null  int64
#  115  room_type_Private room_host_identity_verified_t                                                                    157864 non-null  int64
#  116  room_type_Private room_host_identity_verified_f                                                                    157864 non-null  int64
#  117  room_type_Private room_host_identity_verified_missing_host_identity_verified                                       157864 non-null  int64
#  118  room_type_Entire home/apt_host_identity_verified_t                                                                 157864 non-null  int64
#  119  room_type_Entire home/apt_host_identity_verified_f                                                                 157864 non-null  int64
#  120  room_type_Entire home/apt_host_identity_verified_missing_host_identity_verified                                    157864 non-null  int64
#  121  room_type_Shared room_host_identity_verified_t                                                                     157864 non-null  int64
#  122  room_type_Shared room_host_identity_verified_f                                                                     157864 non-null  int64
#  123  room_type_Private room_bed_type_Real Bed                                                                           157864 non-null  int64
#  124  room_type_Private room_bed_type_Pull-out Sofa                                                                      157864 non-null  int64
#  125  room_type_Private room_bed_type_Futon                                                                              157864 non-null  int64
#  126  room_type_Entire home/apt_bed_type_Real Bed                                                                        157864 non-null  int64
#  127  room_type_Entire home/apt_bed_type_Couch                                                                           157864 non-null  int64
#  128  room_type_Entire home/apt_bed_type_Futon                                                                           157864 non-null  int64
#  129  room_type_Entire home/apt_bed_type_Airbed                                                                          157864 non-null  int64
#  130  room_type_Shared room_bed_type_Real Bed                                                                            157864 non-null  int64
#  131  room_type_Shared room_bed_type_Couch                                                                               157864 non-null  int64
#  132  room_type_Private room_instant_bookable_f                                                                          157864 non-null  int64
#  133  room_type_Private room_instant_bookable_t                                                                          157864 non-null  int64
#  134  room_type_Entire home/apt_instant_bookable_f                                                                       157864 non-null  int64
#  135  room_type_Entire home/apt_instant_bookable_t                                                                       157864 non-null  int64
#  136  room_type_Shared room_instant_bookable_f                                                                           157864 non-null  int64
#  137  room_type_Shared room_instant_bookable_t                                                                           157864 non-null  int64
#  138  room_type_Private room_require_guest_profile_picture_f                                                             157864 non-null  int64
#  139  room_type_Private room_require_guest_profile_picture_t                                                             157864 non-null  int64
#  140  room_type_Entire home/apt_require_guest_profile_picture_f                                                          157864 non-null  int64
#  141  room_type_Entire home/apt_require_guest_profile_picture_t                                                          157864 non-null  int64
#  142  room_type_Shared room_require_guest_profile_picture_f                                                              157864 non-null  int64
#  143  room_type_Private room_require_guest_phone_verification_f                                                          157864 non-null  int64
#  144  room_type_Private room_require_guest_phone_verification_t                                                          157864 non-null  int64
#  145  room_type_Entire home/apt_require_guest_phone_verification_f                                                       157864 non-null  int64
#  146  room_type_Entire home/apt_require_guest_phone_verification_t                                                       157864 non-null  int64
#  147  room_type_Shared room_require_guest_phone_verification_f                                                           157864 non-null  int64
#  148  room_type_Private room_cancellation_policy_moderate                                                                157864 non-null  int64
#  149  room_type_Private room_cancellation_policy_strict_14_with_grace_period                                             157864 non-null  int64
#  150  room_type_Private room_cancellation_policy_flexible                                                                157864 non-null  int64
#  151  room_type_Entire home/apt_cancellation_policy_moderate                                                             157864 non-null  int64
#  152  room_type_Entire home/apt_cancellation_policy_strict_14_with_grace_period                                          157864 non-null  int64
#  153  room_type_Entire home/apt_cancellation_policy_flexible                                                             157864 non-null  int64
#  154  room_type_Entire home/apt_cancellation_policy_super_strict_30                                                      157864 non-null  int64
#  155  room_type_Entire home/apt_cancellation_policy_super_strict_60                                                      157864 non-null  int64
#  156  room_type_Shared room_cancellation_policy_moderate                                                                 157864 non-null  int64
#  157  room_type_Shared room_cancellation_policy_strict_14_with_grace_period                                              157864 non-null  int64
#  158  room_type_Shared room_cancellation_policy_flexible                                                                 157864 non-null  int64
#  159  room_type_Private room_concat_comments_sentiment_positive_sentiment                                                157864 non-null  int64
#  160  room_type_Private room_concat_comments_sentiment_neutral_sentiment                                                 157864 non-null  int64
#  161  room_type_Private room_concat_comments_sentiment_missing_concat_comments_sentiment                                 157864 non-null  int64
#  162  room_type_Private room_concat_comments_sentiment_negative_sentiment                                                157864 non-null  int64
#  163  room_type_Entire home/apt_concat_comments_sentiment_positive_sentiment                                             157864 non-null  int64
#  164  room_type_Entire home/apt_concat_comments_sentiment_neutral_sentiment                                              157864 non-null  int64
#  165  room_type_Shared room_concat_comments_sentiment_positive_sentiment                                                 157864 non-null  int64
#  166  room_type_Shared room_concat_comments_sentiment_neutral_sentiment                                                  157864 non-null  int64
#  167  room_type_Shared room_concat_comments_sentiment_missing_concat_comments_sentiment                                  157864 non-null  int64
#  168  host_response_time_within an hour_host_is_superhost_t                                                              157864 non-null  int64
#  169  host_response_time_within an hour_host_is_superhost_f                                                              157864 non-null  int64
#  170  host_response_time_within a few hours_host_is_superhost_t                                                          157864 non-null  int64
#  171  host_response_time_within a few hours_host_is_superhost_f                                                          157864 non-null  int64
#  172  host_response_time_missing_host_response_time_host_is_superhost_t                                                  157864 non-null  int64
#  173  host_response_time_missing_host_response_time_host_is_superhost_f                                                  157864 non-null  int64
#  174  host_response_time_missing_host_response_time_host_is_superhost_missing_host_is_superhost                          157864 non-null  int64
#  175  host_response_time_within a day_host_is_superhost_t                                                                157864 non-null  int64
#  176  host_response_time_within a day_host_is_superhost_f                                                                157864 non-null  int64
#  177  host_response_time_a few days or more_host_is_superhost_f                                                          157864 non-null  int64
#  178  host_response_time_within an hour_host_has_profile_pic_t                                                           157864 non-null  int64
#  179  host_response_time_within an hour_host_has_profile_pic_f                                                           157864 non-null  int64
#  180  host_response_time_within a few hours_host_has_profile_pic_t                                                       157864 non-null  int64
#  181  host_response_time_missing_host_response_time_host_has_profile_pic_t                                               157864 non-null  int64
#  182  host_response_time_missing_host_response_time_host_has_profile_pic_f                                               157864 non-null  int64
#  183  host_response_time_missing_host_response_time_host_has_profile_pic_missing_host_has_profile_pic                    157864 non-null  int64
#  184  host_response_time_within a day_host_has_profile_pic_t                                                             157864 non-null  int64
#  185  host_response_time_within a day_host_has_profile_pic_f                                                             157864 non-null  int64
#  186  host_response_time_a few days or more_host_has_profile_pic_t                                                       157864 non-null  int64
#  187  host_response_time_a few days or more_host_has_profile_pic_f                                                       157864 non-null  int64
#  188  host_response_time_within an hour_host_identity_verified_t                                                         157864 non-null  int64
#  189  host_response_time_within an hour_host_identity_verified_f                                                         157864 non-null  int64
#  190  host_response_time_within a few hours_host_identity_verified_t                                                     157864 non-null  int64
#  191  host_response_time_within a few hours_host_identity_verified_f                                                     157864 non-null  int64
#  192  host_response_time_missing_host_response_time_host_identity_verified_t                                             157864 non-null  int64
#  193  host_response_time_missing_host_response_time_host_identity_verified_f                                             157864 non-null  int64
#  194  host_response_time_missing_host_response_time_host_identity_verified_missing_host_identity_verified                157864 non-null  int64
#  195  host_response_time_within a day_host_identity_verified_t                                                           157864 non-null  int64
#  196  host_response_time_within a day_host_identity_verified_f                                                           157864 non-null  int64
#  197  host_response_time_a few days or more_host_identity_verified_t                                                     157864 non-null  int64
#  198  host_response_time_a few days or more_host_identity_verified_f                                                     157864 non-null  int64
#  199  host_response_time_within an hour_bed_type_Real Bed                                                                157864 non-null  int64
#  200  host_response_time_within an hour_bed_type_Pull-out Sofa                                                           157864 non-null  int64
#  201  host_response_time_within an hour_bed_type_Couch                                                                   157864 non-null  int64
#  202  host_response_time_within an hour_bed_type_Futon                                                                   157864 non-null  int64
#  203  host_response_time_within an hour_bed_type_Airbed                                                                  157864 non-null  int64
#  204  host_response_time_within a few hours_bed_type_Real Bed                                                            157864 non-null  int64
#  205  host_response_time_within a few hours_bed_type_Pull-out Sofa                                                       157864 non-null  int64
#  206  host_response_time_within a few hours_bed_type_Futon                                                               157864 non-null  int64
#  207  host_response_time_missing_host_response_time_bed_type_Real Bed                                                    157864 non-null  int64
#  208  host_response_time_missing_host_response_time_bed_type_Pull-out Sofa                                               157864 non-null  int64
#  209  host_response_time_missing_host_response_time_bed_type_Couch                                                       157864 non-null  int64
#  210  host_response_time_missing_host_response_time_bed_type_Futon                                                       157864 non-null  int64
#  211  host_response_time_missing_host_response_time_bed_type_Airbed                                                      157864 non-null  int64
#  212  host_response_time_within a day_bed_type_Real Bed                                                                  157864 non-null  int64
#  213  host_response_time_within a day_bed_type_Pull-out Sofa                                                             157864 non-null  int64
#  214  host_response_time_within a day_bed_type_Futon                                                                     157864 non-null  int64
#  215  host_response_time_a few days or more_bed_type_Real Bed                                                            157864 non-null  int64
#  216  host_response_time_a few days or more_bed_type_Pull-out Sofa                                                       157864 non-null  int64
#  217  host_response_time_a few days or more_bed_type_Futon                                                               157864 non-null  int64
#  218  host_response_time_within an hour_instant_bookable_f                                                               157864 non-null  int64
#  219  host_response_time_within an hour_instant_bookable_t                                                               157864 non-null  int64
#  220  host_response_time_within a few hours_instant_bookable_f                                                           157864 non-null  int64
#  221  host_response_time_within a few hours_instant_bookable_t                                                           157864 non-null  int64
#  222  host_response_time_missing_host_response_time_instant_bookable_f                                                   157864 non-null  int64
#  223  host_response_time_missing_host_response_time_instant_bookable_t                                                   157864 non-null  int64
#  224  host_response_time_within a day_instant_bookable_f                                                                 157864 non-null  int64
#  225  host_response_time_within a day_instant_bookable_t                                                                 157864 non-null  int64
#  226  host_response_time_a few days or more_instant_bookable_f                                                           157864 non-null  int64
#  227  host_response_time_a few days or more_instant_bookable_t                                                           157864 non-null  int64
#  228  host_response_time_within an hour_require_guest_profile_picture_f                                                  157864 non-null  int64
#  229  host_response_time_within an hour_require_guest_profile_picture_t                                                  157864 non-null  int64
#  230  host_response_time_within a few hours_require_guest_profile_picture_f                                              157864 non-null  int64
#  231  host_response_time_within a few hours_require_guest_profile_picture_t                                              157864 non-null  int64
#  232  host_response_time_missing_host_response_time_require_guest_profile_picture_f                                      157864 non-null  int64
#  233  host_response_time_missing_host_response_time_require_guest_profile_picture_t                                      157864 non-null  int64
#  234  host_response_time_within a day_require_guest_profile_picture_f                                                    157864 non-null  int64
#  235  host_response_time_within a day_require_guest_profile_picture_t                                                    157864 non-null  int64
#  236  host_response_time_a few days or more_require_guest_profile_picture_f                                              157864 non-null  int64
#  237  host_response_time_a few days or more_require_guest_profile_picture_t                                              157864 non-null  int64
#  238  host_response_time_within an hour_require_guest_phone_verification_f                                               157864 non-null  int64
#  239  host_response_time_within an hour_require_guest_phone_verification_t                                               157864 non-null  int64
#  240  host_response_time_within a few hours_require_guest_phone_verification_f                                           157864 non-null  int64
#  241  host_response_time_within a few hours_require_guest_phone_verification_t                                           157864 non-null  int64
#  242  host_response_time_missing_host_response_time_require_guest_phone_verification_f                                   157864 non-null  int64
#  243  host_response_time_missing_host_response_time_require_guest_phone_verification_t                                   157864 non-null  int64
#  244  host_response_time_within a day_require_guest_phone_verification_f                                                 157864 non-null  int64
#  245  host_response_time_within a day_require_guest_phone_verification_t                                                 157864 non-null  int64
#  246  host_response_time_a few days or more_require_guest_phone_verification_f                                           157864 non-null  int64
#  247  host_response_time_a few days or more_require_guest_phone_verification_t                                           157864 non-null  int64
#  248  host_response_time_within an hour_cancellation_policy_moderate                                                     157864 non-null  int64
#  249  host_response_time_within an hour_cancellation_policy_strict_14_with_grace_period                                  157864 non-null  int64
#  250  host_response_time_within an hour_cancellation_policy_flexible                                                     157864 non-null  int64
#  251  host_response_time_within an hour_cancellation_policy_super_strict_60                                              157864 non-null  int64
#  252  host_response_time_within a few hours_cancellation_policy_moderate                                                 157864 non-null  int64
#  253  host_response_time_within a few hours_cancellation_policy_strict_14_with_grace_period                              157864 non-null  int64
#  254  host_response_time_within a few hours_cancellation_policy_flexible                                                 157864 non-null  int64
#  255  host_response_time_within a few hours_cancellation_policy_super_strict_60                                          157864 non-null  int64
#  256  host_response_time_missing_host_response_time_cancellation_policy_moderate                                         157864 non-null  int64
#  257  host_response_time_missing_host_response_time_cancellation_policy_strict_14_with_grace_period                      157864 non-null  int64
#  258  host_response_time_missing_host_response_time_cancellation_policy_flexible                                         157864 non-null  int64
#  259  host_response_time_missing_host_response_time_cancellation_policy_super_strict_30                                  157864 non-null  int64
#  260  host_response_time_missing_host_response_time_cancellation_policy_super_strict_60                                  157864 non-null  int64
#  261  host_response_time_within a day_cancellation_policy_moderate                                                       157864 non-null  int64
#  262  host_response_time_within a day_cancellation_policy_strict_14_with_grace_period                                    157864 non-null  int64
#  263  host_response_time_within a day_cancellation_policy_flexible                                                       157864 non-null  int64
#  264  host_response_time_a few days or more_cancellation_policy_moderate                                                 157864 non-null  int64
#  265  host_response_time_a few days or more_cancellation_policy_strict_14_with_grace_period                              157864 non-null  int64
#  266  host_response_time_a few days or more_cancellation_policy_flexible                                                 157864 non-null  int64
#  267  host_response_time_within an hour_concat_comments_sentiment_positive_sentiment                                     157864 non-null  int64
#  268  host_response_time_within an hour_concat_comments_sentiment_neutral_sentiment                                      157864 non-null  int64
#  269  host_response_time_within an hour_concat_comments_sentiment_missing_concat_comments_sentiment                      157864 non-null  int64
#  270  host_response_time_within a few hours_concat_comments_sentiment_positive_sentiment                                 157864 non-null  int64
#  271  host_response_time_within a few hours_concat_comments_sentiment_neutral_sentiment                                  157864 non-null  int64
#  272  host_response_time_within a few hours_concat_comments_sentiment_missing_concat_comments_sentiment                  157864 non-null  int64
#  273  host_response_time_missing_host_response_time_concat_comments_sentiment_positive_sentiment                         157864 non-null  int64
#  274  host_response_time_missing_host_response_time_concat_comments_sentiment_neutral_sentiment                          157864 non-null  int64
#  275  host_response_time_missing_host_response_time_concat_comments_sentiment_missing_concat_comments_sentiment          157864 non-null  int64
#  276  host_response_time_missing_host_response_time_concat_comments_sentiment_negative_sentiment                         157864 non-null  int64
#  277  host_response_time_within a day_concat_comments_sentiment_positive_sentiment                                       157864 non-null  int64
#  278  host_response_time_within a day_concat_comments_sentiment_neutral_sentiment                                        157864 non-null  int64
#  279  host_response_time_within a day_concat_comments_sentiment_missing_concat_comments_sentiment                        157864 non-null  int64
#  280  host_response_time_a few days or more_concat_comments_sentiment_positive_sentiment                                 157864 non-null  int64
#  281  host_response_time_a few days or more_concat_comments_sentiment_neutral_sentiment                                  157864 non-null  int64
#  282  host_response_time_a few days or more_concat_comments_sentiment_missing_concat_comments_sentiment                  157864 non-null  int64
#  283  host_is_superhost_t_host_has_profile_pic_t                                                                         157864 non-null  int64
#  284  host_is_superhost_f_host_has_profile_pic_t                                                                         157864 non-null  int64
#  285  host_is_superhost_f_host_has_profile_pic_f                                                                         157864 non-null  int64
#  286  host_is_superhost_missing_host_is_superhost_host_has_profile_pic_missing_host_has_profile_pic                      157864 non-null  int64
#  287  host_is_superhost_t_host_identity_verified_t                                                                       157864 non-null  int64
#  288  host_is_superhost_t_host_identity_verified_f                                                                       157864 non-null  int64
#  289  host_is_superhost_f_host_identity_verified_t                                                                       157864 non-null  int64
#  290  host_is_superhost_f_host_identity_verified_f                                                                       157864 non-null  int64
#  291  host_is_superhost_missing_host_is_superhost_host_identity_verified_missing_host_identity_verified                  157864 non-null  int64
#  292  host_is_superhost_t_bed_type_Real Bed                                                                              157864 non-null  int64
#  293  host_is_superhost_t_bed_type_Pull-out Sofa                                                                         157864 non-null  int64
#  294  host_is_superhost_t_bed_type_Futon                                                                                 157864 non-null  int64
#  295  host_is_superhost_f_bed_type_Real Bed                                                                              157864 non-null  int64
#  296  host_is_superhost_f_bed_type_Futon                                                                                 157864 non-null  int64
#  297  host_is_superhost_f_bed_type_Airbed                                                                                157864 non-null  int64
#  298  host_is_superhost_missing_host_is_superhost_bed_type_Real Bed                                                      157864 non-null  int64
#  299  host_is_superhost_t_instant_bookable_f                                                                             157864 non-null  int64
#  300  host_is_superhost_t_instant_bookable_t                                                                             157864 non-null  int64
#  301  host_is_superhost_f_instant_bookable_f                                                                             157864 non-null  int64
#  302  host_is_superhost_missing_host_is_superhost_instant_bookable_f                                                     157864 non-null  int64
#  303  host_is_superhost_t_require_guest_profile_picture_f                                                                157864 non-null  int64
#  304  host_is_superhost_t_require_guest_profile_picture_t                                                                157864 non-null  int64
#  305  host_is_superhost_f_require_guest_profile_picture_f                                                                157864 non-null  int64
#  306  host_is_superhost_f_require_guest_profile_picture_t                                                                157864 non-null  int64
#  307  host_is_superhost_missing_host_is_superhost_require_guest_profile_picture_f                                        157864 non-null  int64
#  308  host_is_superhost_t_require_guest_phone_verification_f                                                             157864 non-null  int64
#  309  host_is_superhost_t_require_guest_phone_verification_t                                                             157864 non-null  int64
#  310  host_is_superhost_f_require_guest_phone_verification_f                                                             157864 non-null  int64
#  311  host_is_superhost_f_require_guest_phone_verification_t                                                             157864 non-null  int64
#  312  host_is_superhost_missing_host_is_superhost_require_guest_phone_verification_f                                     157864 non-null  int64
#  313  host_is_superhost_t_cancellation_policy_moderate                                                                   157864 non-null  int64
#  314  host_is_superhost_t_cancellation_policy_strict_14_with_grace_period                                                157864 non-null  int64
#  315  host_is_superhost_t_cancellation_policy_flexible                                                                   157864 non-null  int64
#  316  host_is_superhost_t_cancellation_policy_super_strict_60                                                            157864 non-null  int64
#  317  host_is_superhost_f_cancellation_policy_moderate                                                                   157864 non-null  int64
#  318  host_is_superhost_f_cancellation_policy_strict_14_with_grace_period                                                157864 non-null  int64
#  319  host_is_superhost_f_cancellation_policy_flexible                                                                   157864 non-null  int64
#  320  host_is_superhost_f_cancellation_policy_super_strict_30                                                            157864 non-null  int64
#  321  host_is_superhost_f_cancellation_policy_super_strict_60                                                            157864 non-null  int64
#  322  host_is_superhost_missing_host_is_superhost_cancellation_policy_moderate                                           157864 non-null  int64
#  323  host_is_superhost_missing_host_is_superhost_cancellation_policy_flexible                                           157864 non-null  int64
# ...
#  756  host_is_superhost_f                                                                                                157864 non-null  int64
#  757  host_is_superhost_missing_host_is_superhost                                                                        157864 non-null  int64
#  758  host_is_superhost_t                                                                                                157864 non-null  int64
#  759  host_has_profile_pic_f                                                                                             157864 non-null  int64
#  760  host_has_profile_pic_missing_host_has_profile_pic                                                                  157864 non-null  int64
#  761  host_has_profile_pic_t                                                                                             157864 non-null  int64
#  762  host_identity_verified_f                                                                                           157864 non-null  int64
#  763  host_identity_verified_missing_host_identity_verified                                                              157864 non-null  int64
#  764  host_identity_verified_t                                                                                           157864 non-null  int64
#  765  bed_type_Airbed                                                                                                    157864 non-null  int64
#  766  bed_type_Couch                                                                                                     157864 non-null  int64
#  767  bed_type_Futon                                                                                                     157864 non-null  int64
#  768  bed_type_Pull-out Sofa                                                                                             157864 non-null  int64
#  769  bed_type_Real Bed                                                                                                  157864 non-null  int64
#  770  instant_bookable_f                                                                                                 157864 non-null  int64
#  771  instant_bookable_t                                                                                                 157864 non-null  int64
#  772  is_business_travel_ready_f                                                                                         157864 non-null  int64
#  773  require_guest_profile_picture_f                                                                                    157864 non-null  int64
#  774  require_guest_profile_picture_t                                                                                    157864 non-null  int64
#  775  require_guest_phone_verification_f                                                                                 157864 non-null  int64
#  776  require_guest_phone_verification_t                                                                                 157864 non-null  int64
#  777  cancellation_policy_flexible                                                                                       157864 non-null  int64
#  778  cancellation_policy_moderate                                                                                       157864 non-null  int64
#  779  cancellation_policy_strict_14_with_grace_period                                                                    157864 non-null  int64
#  780  cancellation_policy_super_strict_30                                                                                157864 non-null  int64
#  781  cancellation_policy_super_strict_60                                                                                157864 non-null  int64
#  782  concat_comments_sentiment_missing_concat_comments_sentiment                                                        157864 non-null  int64
#  783  concat_comments_sentiment_negative_sentiment                                                                       157864 non-null  int64
#  784  concat_comments_sentiment_neutral_sentiment                                                                        157864 non-null  int64
#  785  concat_comments_sentiment_positive_sentiment                                                                       157864 non-null  int64
#  786  host_response_rate_cat_host_response_rate_0%_to_25%                                                                157864 non-null  int64
#  787  host_response_rate_cat_host_response_rate_25%_to_50%                                                               157864 non-null  int64
#  788  host_response_rate_cat_host_response_rate_missing                                                                  157864 non-null  int64
#  789  size_cat_size_0%_to_25%                                                                                            157864 non-null  int64
#  790  size_cat_size_25%_to_50%                                                                                           157864 non-null  int64
#  791  size_cat_size_50%_to_75%                                                                                           157864 non-null  int64
#  792  size_cat_size_75%_to_100%                                                                                          157864 non-null  int64
#  793  size_cat_size_missing                                                                                              157864 non-null  int64
#  794  avg_dollar_price_in_previous_period_cat_avg_dollar_price_in_previous_period_0%_to_25%                              157864 non-null  int64
#  795  avg_dollar_price_in_previous_period_cat_avg_dollar_price_in_previous_period_25%_to_50%                             157864 non-null  int64
#  796  avg_dollar_price_in_previous_period_cat_avg_dollar_price_in_previous_period_50%_to_75%                             157864 non-null  int64
#  797  avg_dollar_price_in_previous_period_cat_avg_dollar_price_in_previous_period_75%_to_100%                            157864 non-null  int64
#  798  avg_dollar_price_in_previous_period_cat_avg_dollar_price_in_previous_period_missing                                157864 non-null  int64
#  799  concat_comments_subjectivity_cat_concat_comments_subjectivity_0%_to_25%                                            157864 non-null  int64
#  800  concat_comments_subjectivity_cat_concat_comments_subjectivity_25%_to_50%                                           157864 non-null  int64
#  801  concat_comments_subjectivity_cat_concat_comments_subjectivity_50%_to_75%                                           157864 non-null  int64
#  802  concat_comments_subjectivity_cat_concat_comments_subjectivity_75%_to_100%                                          157864 non-null  int64
#  803  concat_comments_subjectivity_cat_concat_comments_subjectivity_missing                                              157864 non-null  int64
#  804  concat_comments_polarity_cat_concat_comments_polarity_0%_to_25%                                                    157864 non-null  int64
#  805  concat_comments_polarity_cat_concat_comments_polarity_25%_to_50%                                                   157864 non-null  int64
#  806  concat_comments_polarity_cat_concat_comments_polarity_50%_to_75%                                                   157864 non-null  int64
#  807  concat_comments_polarity_cat_concat_comments_polarity_75%_to_100%                                                  157864 non-null  int64
#  808  concat_comments_polarity_cat_concat_comments_polarity_missing                                                      157864 non-null  int64
#  809  review_scores_value_cat_review_scores_value_0%_to_25%                                                              157864 non-null  int64
#  810  review_scores_value_cat_review_scores_value_25%_to_50%                                                             157864 non-null  int64
#  811  review_scores_value_cat_review_scores_value_missing                                                                157864 non-null  int64
#  812  review_scores_checkin_cat_review_scores_checkin_0%_to_25%                                                          157864 non-null  int64
#  813  review_scores_checkin_cat_review_scores_checkin_missing                                                            157864 non-null  int64
#  814  review_scores_location_cat_review_scores_location_0%_to_25%                                                        157864 non-null  int64
#  815  review_scores_location_cat_review_scores_location_25%_to_50%                                                       157864 non-null  int64
#  816  review_scores_location_cat_review_scores_location_missing                                                          157864 non-null  int64
#  817  review_scores_communication_cat_review_scores_communication_0%_to_25%                                              157864 non-null  int64
#  818  review_scores_communication_cat_review_scores_communication_missing                                                157864 non-null  int64
#  819  review_scores_accuracy_cat_review_scores_accuracy_0%_to_25%                                                        157864 non-null  int64
#  820  review_scores_accuracy_cat_review_scores_accuracy_missing                                                          157864 non-null  int64
#  821  review_scores_cleanliness_cat_review_scores_cleanliness_0%_to_25%                                                  157864 non-null  int64
#  822  review_scores_cleanliness_cat_review_scores_cleanliness_25%_to_50%                                                 157864 non-null  int64
#  823  review_scores_cleanliness_cat_review_scores_cleanliness_missing                                                    157864 non-null  int64
#  824  review_scores_rating_cat_review_scores_rating_0%_to_25%                                                            157864 non-null  int64
#  825  review_scores_rating_cat_review_scores_rating_25%_to_50%                                                           157864 non-null  int64
#  826  review_scores_rating_cat_review_scores_rating_50%_to_75%                                                           157864 non-null  int64
#  827  review_scores_rating_cat_review_scores_rating_missing                                                              157864 non-null  int64
#  828  reviews_per_month_cat_reviews_per_month_0%_to_25%                                                                  157864 non-null  int64
#  829  reviews_per_month_cat_reviews_per_month_25%_to_50%                                                                 157864 non-null  int64
#  830  reviews_per_month_cat_reviews_per_month_50%_to_75%                                                                 157864 non-null  int64
#  831  reviews_per_month_cat_reviews_per_month_75%_to_100%                                                                157864 non-null  int64
#  832  reviews_per_month_cat_reviews_per_month_missing                                                                    157864 non-null  int64
#  833  DaysPassed_first_review_cat_DaysPassed_first_review_0%_to_25%                                                      157864 non-null  int64
#  834  DaysPassed_first_review_cat_DaysPassed_first_review_25%_to_50%                                                     157864 non-null  int64
#  835  DaysPassed_first_review_cat_DaysPassed_first_review_50%_to_75%                                                     157864 non-null  int64
#  836  DaysPassed_first_review_cat_DaysPassed_first_review_75%_to_100%                                                    157864 non-null  int64
#  837  DaysPassed_first_review_cat_DaysPassed_first_review_missing                                                        157864 non-null  int64
#  838  DaysPassed_last_review_cat_DaysPassed_last_review_0%_to_25%                                                        157864 non-null  int64
#  839  DaysPassed_last_review_cat_DaysPassed_last_review_25%_to_50%                                                       157864 non-null  int64
#  840  DaysPassed_last_review_cat_DaysPassed_last_review_50%_to_75%                                                       157864 non-null  int64
#  841  DaysPassed_last_review_cat_DaysPassed_last_review_75%_to_100%                                                      157864 non-null  int64
#  842  DaysPassed_last_review_cat_DaysPassed_last_review_missing                                                          157864 non-null  int64
#  843  beds_cat_beds_0%_to_25%                                                                                            157864 non-null  int64
#  844  beds_cat_beds_50%_to_75%                                                                                           157864 non-null  int64
#  845  beds_cat_beds_75%_to_100%                                                                                          157864 non-null  int64
#  846  beds_cat_beds_missing                                                                                              157864 non-null  int64
#  847  bathrooms_cat_bathrooms_0%_to_25%                                                                                  157864 non-null  int64
#  848  bathrooms_cat_bathrooms_75%_to_100%                                                                                157864 non-null  int64
#  849  bathrooms_cat_bathrooms_missing                                                                                    157864 non-null  int64
#  850  DaysPassed_host_since_cat_DaysPassed_host_since_0%_to_25%                                                          157864 non-null  int64
#  851  DaysPassed_host_since_cat_DaysPassed_host_since_25%_to_50%                                                         157864 non-null  int64
#  852  DaysPassed_host_since_cat_DaysPassed_host_since_50%_to_75%                                                         157864 non-null  int64
#  853  DaysPassed_host_since_cat_DaysPassed_host_since_75%_to_100%                                                        157864 non-null  int64
#  854  DaysPassed_host_since_cat_DaysPassed_host_since_missing                                                            157864 non-null  int64
#  855  host_total_listings_count_cat_host_total_listings_count_0%_to_25%                                                  157864 non-null  int64
#  856  host_total_listings_count_cat_host_total_listings_count_50%_to_75%                                                 157864 non-null  int64
#  857  host_total_listings_count_cat_host_total_listings_count_75%_to_100%                                                157864 non-null  int64
#  858  host_total_listings_count_cat_host_total_listings_count_missing                                                    157864 non-null  int64
#  859  bedrooms_cat_bedrooms_0%_to_25%                                                                                    157864 non-null  int64
#  860  bedrooms_cat_bedrooms_75%_to_100%                                                                                  157864 non-null  int64
#  861  bedrooms_cat_bedrooms_missing                                                                                      157864 non-null  int64
#  862  sqrt_bedrooms_cat_sqrt_bedrooms_0%_to_25%                                                                          157864 non-null  int64
#  863  sqrt_bedrooms_cat_sqrt_bedrooms_75%_to_100%                                                                        157864 non-null  int64
#  864  sqrt_bedrooms_cat_sqrt_bedrooms_missing                                                                            157864 non-null  int64
# dtypes: float64(48), int64(770), object(47)
# memory usage: 1.0+ GB

# %%
df_flat_file_after_feature_enrichment_info = get_features_info(df_flat_file_after_feature_enrichment, "flat_file_after_feature_enrichment")
df_flat_file_after_feature_enrichment_info.head(5)
# Out:
#                  Feature name                              Source  \
# 0                  listing_id  flat_file_after_feature_enrichment
# 1                        name  flat_file_after_feature_enrichment
# 2    target_start_date_period  flat_file_after_feature_enrichment
# 3      target_end_date_period  flat_file_after_feature_enrichment
# 4  start_date_previous_period  flat_file_after_feature_enrichment
#
#    Unique count   Min       Max  \
# 0         22552  2015  29867352
# 1         21874
# 2             7
# 3             8
# 4             2
#
#                                                Notes
# 0  {'smaple_values': [919931, 21694231, 21606590,...
# 1  {'smaple_values': ['Nomad's Nest - Cosy Room i...
# 2  {'smaple_values': ['2019-05-01', '2019-02-01',...
# 3  {'smaple_values': ['2019-11-08', '2019-05-31',...
# 4  {'smaple_values': ['2018-11-07', '2018-11-09']...

# %%
kaggle_flat_file_features = list(df_kaggle_flat_file_features_info['Feature name'].unique())
df_flat_file_after_feature_enrichment_info = df_flat_file_after_feature_enrichment_info[~df_flat_file_after_feature_enrichment_info['Feature name'].isin(kaggle_flat_file_features)]

# %%
df_data_retrieval_protocol_helper  = pd.concat([df_kaggle_flat_file_features_info,
           df_climatestotravel_berlin_sunshine_hours_info, 
           df_climatestotravel_berlin_average_precipitation_info,
           df_climatestotravel_berlin_average_temperatures_info,
           df_flat_file_after_feature_enrichment_info])

# %%
df_data_retrieval_protocol_helper
# Out:
#                                     Feature name  \
# 0                                     listing_id
# 1                                           name
# 2                       target_start_date_period
# 3                         target_end_date_period
# 4                    target_num_of_day_in_period
# ..                                           ...
# 860            bedrooms_cat_bedrooms_75%_to_100%
# 861                bedrooms_cat_bedrooms_missing
# 862    sqrt_bedrooms_cat_sqrt_bedrooms_0%_to_25%
# 863  sqrt_bedrooms_cat_sqrt_bedrooms_75%_to_100%
# 864      sqrt_bedrooms_cat_sqrt_bedrooms_missing
#
#                                  Source  Unique count   Min       Max  \
# 0                     kaggle_flat_table         22552  2015  29867352
# 1                     kaggle_flat_table         21874
# 2                     kaggle_flat_table             7
# 3                     kaggle_flat_table             8
# 4                     kaggle_flat_table             5    89       100
# ..                                  ...           ...   ...       ...
# 860  flat_file_after_feature_enrichment             2     0         1
# 861  flat_file_after_feature_enrichment             2     0         1
# 862  flat_file_after_feature_enrichment             2     0         1
# 863  flat_file_after_feature_enrichment             2     0         1
# 864  flat_file_after_feature_enrichment             2     0         1
#
#                                                  Notes
# 0    {'smaple_values': [29605459, 23740543, 1282470...
# 1    {'smaple_values': ['Room in Wilmersdorf (only ...
# 2    {'smaple_values': ['2019-05-01', '2019-07-01',...
# 3    {'smaple_values': ['2019-04-30', '2019-11-06',...
# 4    {'smaple_values': [92, 89, 100, 91, 98], 'sum_...
# ..                                                 ...
# 860  {'smaple_values': [0, 1], 'sum_of_na': 0, 'is_...
# 861  {'smaple_values': [1, 0], 'sum_of_na': 0, 'is_...
# 862  {'smaple_values': [0, 1], 'sum_of_na': 0, 'is_...
# 863  {'smaple_values': [1, 0], 'sum_of_na': 0, 'is_...
# 864  {'smaple_values': [0, 1], 'sum_of_na': 0, 'is_...
#
# [924 rows x 6 columns]

# %%
df_data_retrieval_protocol_helper.to_csv('data_retrieval_protocol_helper.csv')
